# %%
import torch
model = torch.load("./best_model.pt", weights_only=False)
for graph in model:
        print(graph)
        print(model[graph])
        print()
# Out:
# architecture
# GraphSAGE
# in_channels
# 4
# hidden_channels
# 64
# num_layers
# 3
# out_channels
# 1
# encoder
# OrderedDict([('convs.0.lin_l.weight', tensor([[-0.2810, -0.2503,  0.0644,  0.1415],
#         [ 0.2816, -0.0092,  0.1419,  0.2313],
#         [-0.1906, -0.0882, -0.1194,  0.0053],
#         [-0.1053,  0.0301, -0.2352,  0.0836],
#         [ 0.5036,  0.3175,  0.0041,  0.4334],
#         [ 0.3973, -0.0717, -0.2941,  0.1529],
#         [-0.3927,  0.1102, -0.2786,  0.2418],
#         [-0.0426,  0.3357,  0.3424,  0.3105],
#         [ 0.2916, -0.2160, -0.4450, -0.4640],
#         [ 0.1626,  0.0618, -0.3801,  0.1542],
#         [ 0.0408, -0.3680, -0.4592, -0.2681],
#         [ 0.0122, -0.1188,  0.2954,  0.0987],
#         [ 0.1252,  0.1471,  0.1655, -0.0540],
#         [ 0.3120,  0.3186, -0.0459,  0.2885],
#         [ 0.0885, -0.0336, -0.0667, -0.2867],
#         [ 0.1594, -0.3627, -0.0726,  0.0913],
#         [-0.1395,  0.0009, -0.1648,  0.1639],
# ...
